# %%
import torch
print(torch.backends.cudnn.version())
print(torch.__version__)
# Out:
# 8500
# 1.13.1+cu117

# %% [markdown]
# # 推理

# %%
from IPython.display import Audio
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"  # 多行都显示
import utils_audio
from text2speech import Text2Speech as Text2Speech_vits

# 使用当前正在训练的ckpt
# M_tts = Text2Speech_vits(model_dir="/root/autodl-tmp/VITS_MODELS/OUTPUT_MODEL_四郎/G_latest.pth",
#                     config_fp="/root/autodl-tmp/VITS_MODELS/OUTPUT_MODEL_四郎/config.json").init()


M_tts = Text2Speech_vits(model_dir="OUTPUT_MODEL/G_latest.pth",
                    config_fp="OUTPUT_MODEL/config.json").init()

sr, wav = M_tts.tts_fn(text="Hello, I'm trump，nice to meet you. 我是特朗普，祝福桑达科技。Best wishes to sounda tech.",
                         speaker="trump",
                         language="auto",  # 用Mix的话就相当于直接读字母发音了
                         text_cleaners=M_tts.hparams['data']['text_cleaners'],
                         speed=1)

utils_audio.save_audio(wav, sr, fp="./mock_vits.wav")
Audio("./mock_vits.wav")
# Out:
# INFO:root:Loaded checkpoint 'OUTPUT_MODEL/G_latest.pth' (iteration 207)
# DEBUG:root:marked text is '[EN]Hello[EN],[EN] I[EN]'[EN]m trump[EN]，[EN]nice to meet you[EN].[EN] [EN][ZH]我是特朗普[ZH]，[ZH]祝福桑达科技[ZH]。[EN]Best wishes to sounda tech[EN].'
# DEBUG:root: use speaker:trump speaker_id:0
# DEBUG:root:>>> func:text_to_sequence params as follow:
# DEBUG:root:  [text]: [EN]Hello[EN],[EN] I[EN]'[EN]m trump[EN]，[EN]nice to meet you[EN].[EN] [EN][ZH]我是特朗普[ZH]，[ZH]祝福桑达科技[ZH]。[EN]Best wishes to sounda tech[EN].
# DEBUG:root:  [symbols]: ['_', ',', '.', '!', '?', '-', '~', '…', 'N', 'Q', 'a', 'b', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'n', 'o', 'p', 's', 't', 'u', 'v', 'w', 'x', 'y', 'z', 'ɑ', 'æ', 'ʃ', 'ʑ', 'ç', 'ɯ', 'ɪ', 'ɔ', 'ɛ', 'ɹ', 'ð', 'ə', 'ɫ', 'ɥ', 'ɸ', 'ʊ', 'ɾ', 'ʒ', 'θ', 'β', 'ŋ', 'ɦ', '⁼', 'ʰ', '`', '^', '#', '*', '=', 'ˈ', 'ˌ', '→', '↓', '↑', ' ']
# DEBUG:root:  [cleaner_names]: ['cjke_cleaners2']
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# DEBUG:jieba:Loading model from cache /tmp/jieba.cache
# Loading model cost 0.583 seconds.
# DEBUG:jieba:Loading model cost 0.583 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.
# DEBUG:root: clean_text: hɛˈloʊ ,aɪ 'ɛm tɹəmp ，nis tɪ mit ju . wo↓↑ s`ɹ`↓ tʰə↓lɑŋ↓↑pʰu↓↑ ，ts`⁼u↓fu↑ sɑŋ→t⁼a↑ kʰə→tʃ⁼i↓ 。bɛst ˈwɪʃɪz tɪ sounda* tɛk .
# DEBUG:root: length-text:123
# DEBUG:root: length-seq:119
# DEBUG:root: ignored-symbol: '',，,，,。'
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sr, wav = M_tts.tts_fn(text="致以诚挚的问候和美好的祝愿",
                         speaker="四郎配音",
                         language="auto",  # 用Mix的话就相当于直接读字母发音了
                         text_cleaners=M_tts.hparams['data']['text_cleaners'],
                         speed=1)

utils_audio.save_audio(wav, sr, fp="./mock_vits.wav")
Audio("./mock_vits.wav")


sr, wav = M_tts.tts_fn(text="致以诚挚的问候和美好的祝愿",
                         speaker="daniel",
                         language="auto",  # 用Mix的话就相当于直接读字母发音了
                         text_cleaners=M_tts.hparams['data']['text_cleaners'],
                         speed=1)

utils_audio.save_audio(wav, sr, fp="./mock_vits.wav")
Audio("./mock_vits.wav")
# Out:
# DEBUG:root:marked text is '[ZH]致以诚挚的问候和美好的祝愿[ZH]。[EN]Nice to meet you[EN]'
# DEBUG:root: use speaker:四郎配音 speaker_id:2
# DEBUG:root:>>> func:text_to_sequence params as follow:
# DEBUG:root:  [text]: [ZH]致以诚挚的问候和美好的祝愿[ZH]。[EN]Nice to meet you[EN]
# DEBUG:root:  [symbols]: ['_', ',', '.', '!', '?', '-', '~', '…', 'N', 'Q', 'a', 'b', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'n', 'o', 'p', 's', 't', 'u', 'v', 'w', 'x', 'y', 'z', 'ɑ', 'æ', 'ʃ', 'ʑ', 'ç', 'ɯ', 'ɪ', 'ɔ', 'ɛ', 'ɹ', 'ð', 'ə', 'ɫ', 'ɥ', 'ɸ', 'ʊ', 'ɾ', 'ʒ', 'θ', 'β', 'ŋ', 'ɦ', '⁼', 'ʰ', '`', '^', '#', '*', '=', 'ˈ', 'ˌ', '→', '↓', '↑', ' ']
# DEBUG:root:  [cleaner_names]: ['cjke_cleaners2']
# DEBUG:root: clean_text: ts`⁼ɹ`↓i↓↑ ts`ʰəŋ↑ts`⁼ɹ`↓ t⁼ə wən↓xoʊ↓ xə↑ meɪ↓↑xɑʊ↓↑ t⁼ə ts`⁼u↓ɥæn↓ 。nis tɪ mit ju.
# DEBUG:root: length-text:84
# DEBUG:root: length-seq:83
# DEBUG:root: ignored-symbol: '。'
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# DEBUG:root:marked text is '[ZH]致以诚挚的问候和美好的祝愿[ZH]'
# DEBUG:root: use speaker:daniel speaker_id:1
# DEBUG:root:>>> func:text_to_sequence params as follow:
# DEBUG:root:  [text]: [ZH]致以诚挚的问候和美好的祝愿[ZH]
# DEBUG:root:  [symbols]: ['_', ',', '.', '!', '?', '-', '~', '…', 'N', 'Q', 'a', 'b', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'n', 'o', 'p', 's', 't', 'u', 'v', 'w', 'x', 'y', 'z', 'ɑ', 'æ', 'ʃ', 'ʑ', 'ç', 'ɯ', 'ɪ', 'ɔ', 'ɛ', 'ɹ', 'ð', 'ə', 'ɫ', 'ɥ', 'ɸ', 'ʊ', 'ɾ', 'ʒ', 'θ', 'β', 'ŋ', 'ɦ', '⁼', 'ʰ', '`', '^', '#', '*', '=', 'ˈ', 'ˌ', '→', '↓', '↑', ' ']
# DEBUG:root:  [cleaner_names]: ['cjke_cleaners2']
# DEBUG:root: clean_text: ts`⁼ɹ`↓i↓↑ ts`ʰəŋ↑ts`⁼ɹ`↓ t⁼ə wən↓xoʊ↓ xə↑ meɪ↓↑xɑʊ↓↑ t⁼ə ts`⁼u↓ɥæn↓.
# DEBUG:root: length-text:69
# DEBUG:root: length-seq:69
# DEBUG:root: ignored-symbol: ''
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sr, wav = M_tts.tts_fn(text="这是一条测试音频，一二三四，我是桑达科技的创始人程晓敏，吹风磁暴救救我",
                         speaker="四郎配音",
                         language="auto",  # 用Mix的话就相当于直接读字母发音了
                         text_cleaners=M_tts.hparams['data']['text_cleaners'],
                         speed=1)

utils_audio.save_audio(wav, sr, fp="./mock_vits.wav")
Audio("./mock_vits.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 播放本地音频

# %%
from IPython.display import Audio
Audio("./OUTPUT_MODEL/mock_2000.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 基座模型推理

# %%
from IPython.display import Audio
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"  # 多行都显示
import utils_audio
from text2speech import Text2Speech as Text2Speech_vits


M_tts = Text2Speech_vits(model_dir="/root/autodl-tmp/pretrained_models_CJE/G_0.pth",
                    config_fp="/root/autodl-tmp/pretrained_models_CJE/finetune_speaker_CJE.json").init()


sr, wav = M_tts.tts_fn(text="这是一条测试音频",
                         speaker="钟离 Zhongli (Genshin Impact)",
                         language="auto",  # 用Mix的话就相当于直接读字母发音了
                         text_cleaners=M_tts.hparams['data']['text_cleaners'],
                         speed=1)

utils_audio.save_audio(wav, sr, fp="./mock_vits.wav")
Audio("./mock_vits.wav")
# Out:
# INFO:root:Loaded checkpoint '/root/autodl-tmp/pretrained_models_CJE/G_0.pth' (iteration 419)
# DEBUG:root:marked text is '[ZH]这是一条测试音频[ZH]'
# DEBUG:root: use speaker:钟离 Zhongli (Genshin Impact) speaker_id:106
# DEBUG:root:>>> func:text_to_sequence params as follow:
# DEBUG:root:  [text]: [ZH]这是一条测试音频[ZH]
# DEBUG:root:  [symbols]: ['_', ',', '.', '!', '?', '-', '~', '…', 'N', 'Q', 'a', 'b', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'n', 'o', 'p', 's', 't', 'u', 'v', 'w', 'x', 'y', 'z', 'ɑ', 'æ', 'ʃ', 'ʑ', 'ç', 'ɯ', 'ɪ', 'ɔ', 'ɛ', 'ɹ', 'ð', 'ə', 'ɫ', 'ɥ', 'ɸ', 'ʊ', 'ɾ', 'ʒ', 'θ', 'β', 'ŋ', 'ɦ', '⁼', 'ʰ', '`', '^', '#', '*', '=', 'ˈ', 'ˌ', '→', '↓', '↑', ' ']
# DEBUG:root:  [cleaner_names]: ['cjke_cleaners2']
# DEBUG:root: clean_text: ts`⁼ə↓s`ɹ`↓ i→tʰiɑʊ↑ tsʰə↓s`ɹ`↓ in→pʰin↑.
# DEBUG:root: length-text:41
# DEBUG:root: length-seq:41
# DEBUG:root: ignored-symbol: ''
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
M_tts.add_lang_mark("这是一条测试音频")
# Out:
# '[ZH]这是一条测试音频[ZH]'
