# %%
from sounda_voice.text2speech import Text2Speech as Text2Speech_sounda
from text2speech import Text2Speech as Text2Speech_vits
import pypinyin
from IPython.display import Audio
import utils_audio
import os

# %% [markdown]
# # Sounda

# %%
pypinyin.load_phrases_dict({"映射测试": [["ce4"], ["shi4"], ["ying4"], ["she4"]]}, style=pypinyin.Style.TONE3)

M = Text2Speech_sounda(encoder_fp="/root/models/pretrained1.pt",
                synth_fp="/root/models/model_zn_v2.pt",  # ~/models/pretrained-11-7-21_75k.pt
                vocoder_fp="/root/models/g_hifigan.pt")

# M = Text2Speech_sounda(encoder_fp="/root/models/pretrained1.pt",
#                 synth_fp="/root/models/pretrained-11-7-21_75k.pt",  # 
#                 vocoder_fp="/root/models/g_hifigan.pt")

M.init()
# Out:
# Loaded encoder "pretrained1.pt" trained to step 1594501
# Building hifigan
# Loading '/root/models/g_hifigan.pt'
# Complete.
# Removing weight norm...

# %%
text1 = "今天天气不错"
text2 = "连续语音测试特殊符号「测试」，阿拉伯数字测试1234，需要单独拼音映射吗，长句测试样例"
# text1 = "现在效果不好就是因为没有覆盖到"

text = text1
mock_audio_fp = "/root/audio_samples/female_p1_zh.wav"
# mock_audio_fp = "/root/audio_samples/haichao.wav"

wav, sr = M.synth_file(text, mock_audio_fp)
print(type(wav), wav.shape, sr)

utils_audio.save_audio(wav, sr, fp="./mock_"+os.path.basename(mock_audio_fp))
Audio("./mock_"+os.path.basename(mock_audio_fp))
# Out:
# /root/miniconda3/lib/python3.8/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# sample_rate from librosa.load is 22050
# \Loading the json with %s
#  /root/models/config_16k.json
# Trainable Parameters: 0.000M
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [54], in <cell line: 9>()
#       6 mock_audio_fp = "/root/audio_samples/female_p1_zh.wav"
#       7 # mock_audio_fp = "/root/audio_samples/haichao.wav"
# ----> 9 wav, sr = M.synth_file(text, mock_audio_fp)
#      10 print(type(wav), wav.shape, sr)
#      12 utils_audio.save_audio(wav, sr, fp="./mock_"+os.path.basename(mock_audio_fp))
#
# File ~/Serving_VITS-fast-fine-tuning/sounda_voice/text2speech.py:111, in Text2Speech.synth_file(self, texts, mock_audio_fp)
#     107 #print("processed-text: %s" % texts)
#     108
#     109 # synthesize and vocode
#     110 embeds = [embed] * len(texts)
# --> 111 specs = self.current_synt.synthesize_spectrograms(texts, embeds)
#     112 spec = np.concatenate(specs, axis=1)
#     113 sample_rate = Synthesizer.sample_rate
#
# File ~/Serving_VITS-fast-fine-tuning/sounda_voice/function/synthesizer/inference.py:91, in Synthesizer.synthesize_spectrograms(self, texts, embeddings, return_alignments, style_idx, min_stop_token, steps)
#      89 # Load the model on the first request.
#      90 if not self.is_loaded():
# ---> 91     self.load()
#      93     # Print some info about the model when it is loaded
#      94     tts_k = self._model.get_step() // 1000
#
# File ~/Serving_VITS-fast-fine-tuning/sounda_voice/function/synthesizer/inference.py:69, in Synthesizer.load(self)
#      51 """
#      52 Instantiates and loads the model given the weights file that was passed in the constructor.
#      53 """
#      54 self._model = Tacotron(embed_dims=hparams.tts_embed_dims,
#      55                        num_chars=len(symbols),
#      56                        encoder_dims=hparams.tts_encoder_dims,
#    (...)
#      66                        stop_threshold=hparams.tts_stop_threshold,
#      67                        speaker_embedding_size=hparams.speaker_embedding_size).to(self.device)
# ---> 69 self._model.load(self.model_fpath, self.device)
#      70 self._model.eval()
#      72 if self.verbose:
#
# File ~/Serving_VITS-fast-fine-tuning/sounda_voice/function/synthesizer/models/base.py:50, in Base.load(self, path, device, optimizer)
#      48 def load(self, path, device, optimizer=None):
#      49     # Use device of model params as location for loaded state
# ---> 50     checkpoint = torch.load(str(path), map_location=device)
#      51     if "model_state" in checkpoint:
#      52         state = checkpoint["model_state"]
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/serialization.py:777, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     772 if _is_zipfile(opened_file):
#     773     # The zipfile reader is going to advance the current file position.
#     774     # If we want to actually tail call to torch.jit.load, we need to
#     775     # reset back to the original position.
#     776     orig_position = opened_file.tell()
# --> 777     with _open_zipfile_reader(opened_file) as opened_zipfile:
#     778         if _is_torchscript_zip(opened_zipfile):
#     779             warnings.warn("'torch.load' received a zip file that looks like a TorchScript archive"
#     780                           " dispatching to 'torch.jit.load' (call 'torch.jit.load' directly to"
#     781                           " silence this warning)", UserWarning)
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/serialization.py:282, in _open_zipfile_reader.__init__(self, name_or_buffer)
#     281 def __init__(self, name_or_buffer) -> None:
# --> 282     super(_open_zipfile_reader, self).__init__(torch._C.PyTorchFileReader(name_or_buffer))
#
# RuntimeError: PytorchStreamReader failed reading zip archive: failed finding central directory

# %% [markdown]
# # VITS

# %%
M_tts = Text2Speech_vits(model_dir="/root/VITS-fast-fine-tuning/OUTPUT_MODEL/G_latest.pth",
                    config_fp="/root/VITS-fast-fine-tuning/OUTPUT_MODEL/config.json").init()

sr, wav = M_tts.tts_fn(text="这里是一段测试音频1234，我是桑达科技的创始人程晓敏，吹风磁暴救救我",
                         speaker="四郎配音",
                         language="auto",  # 用Mix的话就相当于直接读字母发音了
                         text_cleaners=["chinese_cleaners"],
                         speed=1.0)

utils_audio.save_audio(wav, sr, fp="./mock_vits.wav")
Audio("./mock_vits.wav")
# Out:
# INFO:root:Loaded checkpoint '/root/VITS-fast-fine-tuning/OUTPUT_MODEL/G_latest.pth' (iteration 191)
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !git branch -vv
# Out:
#   main            b1403af [origin/main] some fmt.
# * refactor_server 4345309 [origin/refactor_server] debug mode
